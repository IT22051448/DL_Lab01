# %% [markdown]
# # Task 2

# %% [markdown]
# 01. Create a new dataframe by filtering all the columns [i.e., features] except N_total, N_bulk,
# N_surface and R_avg columns

# %%
import pandas as pd
df = pd.read_csv('Au_nanoParticle_dataset.csv')
df.head()
# Out:
#    ID    T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# 0   1  273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 1   2  273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 2   3  273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 3   4  273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 4   5  273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#      R_max  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  q6q6_S19  \
# 0  19.4516  ...         0         0         0         0         0         0
# 1  24.1755  ...         0         0         0         0         0         0
# 2  31.0305  ...         0         0         0         0         0         0
# 3  37.8795  ...         0         0         0         0         0         0
# 4  39.7614  ...         0         0         0         0         0         0
#
# ...

# %%
filtered_df = df[['N_total', 'N_bulk', 'N_surface', 'R_avg']]
filtered_df.head()
# Out:
#    N_total  N_bulk  N_surface    R_avg
# 0     1599    1014        585  17.3706
# 1     1642    1034        608  17.6061
# 2     4637    3365       1272  25.3692
# 3     7189    5292       1897  29.7011
# 4    11004    8508       2496  34.2831

# %% [markdown]
# 02. Display the first 20 samples of this dataframe

# %%
filtered_df.head(20)
# Out:
#     N_total  N_bulk  N_surface    R_avg
# 0      1599    1014        585  17.3706
# 1      1642    1034        608  17.6061
# 2      4637    3365       1272  25.3692
# 3      7189    5292       1897  29.7011
# 4     11004    8508       2496  34.2831
# 5     13375   10768       2607  36.6334
# 6     13795   11155       2640  37.0108
# 7     13947   11304       2643  37.1672
# 8     14020   11357       2663  37.2103
# 9     14056   11389       2667  37.2467
# 10     1534     966        568  17.1107
# 11     1559     974        585  17.2101
# 12     4356    3099       1257  24.8253
# 13     6550    4675       1875  29.0376
# 14    10175    7748       2427  33.4399
# 15    12393    9842       2551  35.6950
# 16    13207   10590       2617  36.4657
# 17    13543   10937       2606  36.7871
# 18    13713   11079       2634  36.9333
# 19    13791   11151       2640  37.0104

# %% [markdown]
# 03. Calculate the mean, standard deviation and quartile values for each of the above 4 features.

# %%
filtered_df.describe().loc[['mean', 'std', '25%', '50%', '75%']]
# Out:
#           N_total       N_bulk   N_surface      R_avg
# mean  3476.786500  2521.550250   955.23625  20.654363
# std   3679.286769  2976.232459   721.87022   7.610716
# 25%   1061.000000   618.750000   437.00000  15.160725
# 50%   1867.000000  1199.000000   666.00000  18.629250
# 75%   4503.000000  3183.000000  1301.75000  25.525125

# %% [markdown]
# 04. Plot the histogram of each of these features in a 1x4 layout.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 5))

plt.subplot(1, 4, 1)
plt.hist(filtered_df['N_total'], bins=100, color='blue', alpha=0.7)
plt.title('N_total Distribution')
plt.xlabel('N_total')
plt.ylabel('Frequency')

plt.subplot(1, 4, 2)
plt.hist(filtered_df['N_bulk'], bins=100, color='red', alpha=0.7)
plt.title('N_bulk Distribution')
plt.xlabel('N_bulk')

plt.subplot(1, 4, 3)
plt.hist(filtered_df['N_surface'], bins=100, color='orange', alpha=0.7)
plt.title('N_surface Distribution')
plt.xlabel('N_surface')

plt.subplot(1, 4, 4)
plt.hist(filtered_df['R_avg'], bins=100, color='purple', alpha=0.7)
plt.title('R_avg Distribution')
plt.xlabel('R_avg')


plt.tight_layout()
plt.show()

# %% [markdown]
# 05. Visualize the scatter plots and histograms of this dataframe using the pairplot functionality of seaborn library

# %%
import seaborn as sns
sns.pairplot(filtered_df, diag_kind='hist', corner=False)

plt.suptitle("Pairplot of N_total, N_bulk, N_surface, R_avg", y=1.02, fontsize=14)
plt.show()

# %% [markdown]
# 06. Add the below code and change it such that,

# %% [markdown]
# a. Plots on the diagonal contains the histogram of each feature along with the kernal
# density estimation plot. <br>
# b. Plots on the lower half [g.map_lower] contains the bivariate kernal density
# estimation plot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


g = sns.PairGrid(filtered_df)

g.map_upper(sns.histplot)

g.map_diag(sns.histplot, kde=True)

g.map_lower(sns.kdeplot, fill=True, cmap="Blues", thresh=0.05)

plt.suptitle("PairGrid with Histograms, KDE, and Bivariate KDE", y=1.02, fontsize=14)

plt.show()
